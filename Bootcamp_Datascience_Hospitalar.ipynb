# %% [markdown]
# <a href="https://colab.research.google.com/github/cajjunior/bootcamp_dataScience_alura/blob/main/Bootcamp_Datascience_Hospitalar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Módulo 1

# %% [markdown]
# ## Aula 1

# %% [markdown]
# Exploração dos dados do Datasus de 2008 em diante

# %%
import pandas as pd

# %%
# aula 1.2 e 1.3 (base de dados no git hub)
#URL = 'https://raw.githubusercontent.com/alura-cursos/agendamento-hospitalar/main/dados/A151346189_28_143_208.csv'

# Aula 2
URL = 'https://raw.githubusercontent.com/alura-cursos/agendamento-hospitalar/main/dados/A160324189_28_143_208.csv'

# %%
# Leitura de arquivo csv em um DataFrame
dados = pd.read_csv(
    URL, 
    encoding="ISO-8859-1",
    # pular 3 linhas
    skiprows = 3,
    # def separador
    sep=";",
    # elimina linhas finais
    skipfooter=12,
    # indicador de separador de milhares
    thousands=".", 
    # indicador de numeral decimal
    decimal=",")
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %%
# Exibir 5 primeiras linhas do DataFrame
dados.head()
# Out:
#   Unidade da Federação 1992/Mar  ...     2020/Ago         Total
# 0          11 Rondônia        -  ...   3556381.57  9.291297e+08
# 1              12 Acre        -  ...            -  4.206680e+08
# 2          13 Amazonas        -  ...   4726485.73  1.771655e+09
# 3           14 Roraima        -  ...   1524478.04  3.050109e+08
# 4              15 Pará        -  ...  11559714.54  4.437116e+09
#
# [5 rows x 280 columns]

# %%
# Exibir 5 últimas linhas do DataFrame
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar  ...     2020/Ago         Total
# 22   43 Rio Grande do Sul        -  ...  28349257.38  1.195865e+10
# 23  50 Mato Grosso do Sul        -  ...   4059220.22  2.172158e+09
# 24         51 Mato Grosso        -  ...   6174224.99  2.036924e+09
# 25               52 Goiás        -  ...  20242641.73  4.657349e+09
# 26    53 Distrito Federal        -  ...  12044848.02  2.429933e+09
#
# [5 rows x 280 columns]

# %%
#localização estado específico de 2020/Jan em diante
dados.set_index('Unidade da Federação').loc['12 Acre', '2020/Jan':]
# Out:
# 2020/Jan      3261123.88
# 2020/Fev      2981264.22
# 2020/Mar      2859102.06
# 2020/Abr      2472063.08
# 2020/Mai      2383895.48
# 2020/Jun       2199920.7
# 2020/Jul      1163813.08
# 2020/Ago               -
# Total       420668039.63
# Name: 12 Acre, dtype: object

# %%
#selecionando duas datas
dados[['2008/Ago', '2008/Set']].head()
# Out:
#       2008/Ago     2008/Set
# 0   2938286.29   2843930.91
# 1   1886871.84   2084884.80
# 2   8331763.97   8148089.92
# 3   1045291.11   1003740.89
# 4  23259148.28  23667690.01

# %%
# Lista as colunas do DataFrame
dados.columns
# Out:
# Index(['Unidade da Federação', '1992/Mar', '1992/Abr', '1993/Mai', '1993/Dez',
#        '1994/Jan', '1994/Fev', '1994/Mai', '1994/Ago', '1994/Nov',
#        ...
#        '2019/Dez', '2020/Jan', '2020/Fev', '2020/Mar', '2020/Abr', '2020/Mai',
#        '2020/Jun', '2020/Jul', '2020/Ago', 'Total'],
#       dtype='object', length=280)

# %%
#Exibe média de cada coluna numérica
dados.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Abr    4.000568e+07
# 2020/Mai    4.676903e+07
# 2020/Jun    4.536735e+07
# 2020/Jul    4.071708e+07
# Total       5.993724e+09
# Length: 157, dtype: float64

# %%
# Exibe informações básicas do DataFrame
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 280 entries, Unidade da Federação to Total
# dtypes: float64(157), object(123)
# memory usage: 59.2+ KB

# %%
# Define uma formatação para o formato tipo float
pd.options.display.float_format = "{:,.2f}".format

# %%
dados.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# 2007/Ago         304,952.77
# 2007/Set         788,145.26
# 2007/Out       2,440,162.96
# 2007/Nov       5,517,354.05
# 2007/Dez      12,337,159.42
#                  ...
# 2020/Abr      40,005,678.92
# 2020/Mai      46,769,027.82
# 2020/Jun      45,367,349.74
# 2020/Jul      40,717,083.95
# Total      5,993,724,452.01
# Length: 157, dtype: float64

# %%
dados['2008/Ago']
# Out:
# 0      2,938,286.29
# 1      1,886,871.84
# 2      8,331,763.97
# 3      1,045,291.11
# 4     23,259,148.28
# 5      1,550,340.63
# 6      5,213,290.38
# 7     14,609,872.57
# 8     10,645,917.52
# 9     29,304,821.51
# 10    10,812,840.19
# 11    12,673,774.35
# 12    31,705,296.79
# 13     9,262,767.68
# 14     4,543,252.50
# 15    43,254,543.33
# 16    80,374,117.08
# 17    12,384,068.19
# 18    42,487,939.51
# 19   179,898,070.22
# 20    56,699,001.13
# 21    28,887,854.62
# 22    56,233,758.74
# 23     9,602,843.49
# 24     8,987,811.95
# 25    21,041,071.33
# 26    11,548,451.89
# Name: 2008/Ago, dtype: float64

# %%
# Calcula a média dos dados da coluna 2008/Ago
dados['2008/Ago'].mean()
# Out:
# 26636409.892222222

# %%
# Cria um gráfico (plot) de linha cruanzdo os valores da coluna
# UF no eixo x e a coluna data no eixo y
dados.plot(x="Unidade da Federação", y="2008/Ago")

# %% [markdown]
# Descrição do gráfico
#
#
# *   Título: Sem título
# *   Base de dados utilizada: Variável dados
# *   Tipo de gráfico: Linha
# *   Eixo X: Estadoa
# *   Eixo Y: Valores de agosto de 2008
# *   O que está sendo mostrado: Foi criado um gráfico de linha dos 26 Estados Brasileiros mais o Distrito Federal relacionando ao seu custo por internação referente ao mês de agosto de 2008.

# %%
# Cria um gráfico (plot) de barras cruzando os valores da coluna
# "Unidade da Federação" no eixo x e a coluna "2008/Ago" no eixo y
dados.plot(
    x='Unidade da Federação', 
    y='2008/Ago', 
    # tipo de grafico
    kind='bar',
    # tamanho de gráfico 
    figsize=(9,6), 
    # título
    title='Gastos com internação por UF')

# %% [markdown]
# Descrição do gráfico
#
# * Título: Gastos de saúde por UF
# * Base de dados utilizada: Variável dados
# * Tipo de gráfico:Barras
# * Eixo X: Estados
# * Eixo Y: Valores de agosto de 2008
# * O que está sendo mostrado: Foi criado um gráfico de barra dos 26 Estados Brasileiros mais o Distrito Federal relacionando ao seu custo por internação referente ao mês de agosto de 2008, com a escala de valores no eixo Y pouco intuitiva.

# %%
#importando matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x='Unidade da Federação', y='2008/Ago', kind='bar', figsize=(9,6))

# Define uma formatação a ser aplicada nos valores do eixo y
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
# ajuste na legenda eixo x, rotação 45 graus a direita
ax.set_xticklabels( dados['Unidade da Federação'], rotation=45, ha='right')

# Definir título
plt.title("Valor gasto com internação por Unidade de federação")
# oculta info do gráfico
plt.show()

# %% [markdown]
# Descrição gráfico
#
# * Título: Valor gasto com internação por Unidade de federação
# * Base de dados utilizada: Variável dados
# * Tipo de gráfico: Barra
# * Eixo X: Estados
# * Eixo Y: Valores de agosto de 2008
# * O que está sendo mostrado: Foi criado um gráfico de barra dos 26 Estados Brasileiros mais o Distrito Federal relacionando ao seu custo por internação referente ao mês de agosto de 2008 com a correção da escala de valores no eixo Y descrito em milhões.

# %% [markdown]
# ## Desafios Aula 1

# %% [markdown]
# ## Desafio: escolher um título mais descritivo, que passe a  mensagem adequada.

# %%
#importando matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x='Unidade da Federação', y='2008/Ago', kind='bar', figsize=(9,6))

# Define uma formatação a ser aplicada nos valores do eixo y
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
# ajuste na legenda eixo x, rotação 45 graus a direita
ax.set_xticklabels( dados['Unidade da Federação'], rotation=45, ha='right')

# Definir título
plt.title("Valor gasto com internação no SIH/SUS por estado brasileiro de agosto de 2008")
# oculta info do gráfico
plt.show()

# %% [markdown]
# Descrição gráfico
#
# * Título: Valor gasto com internação no SIH/SUS por estado brasileiro de agosto de 2008
# * Base de dados utilizada: Variável dados
# * Tipo de gráfico: Barra
# * Eixo X: Estados
# * Eixo Y: Valores de agosto de 2008
# * O que está sendo mostrado: Foi criado um gráfico de barra dos 26 Estados Brasileiros mais o Distrito Federal relacionando ao seu custo por internação referente ao mês de agosto de 2008 com a correção da escala de valores no eixo Y descrito em milhões.

# %% [markdown]
# ## Desafio: faça a mesma análise para o mês mais recente.

# %%
# Pegaremos a penúltima pois a última é a Total
dados.columns[-1]
# Out:
# 'Total'

# %%
# Penúltima coluna
dados.columns[-2]
# Out:
# '2020/Ago'

# %%
# nomeando variavel para dados mais recentes 
mes_mais_recente = dados.columns[-2]
mes_mais_recente
# Out:
# '2020/Ago'

# %%
# Esse mês possui dados inválidos (caractere "-"), vamos substiruir esses valore por 0 e converter a coluna para float
dados['2020/Ago'] = dados['2020/Ago'].replace("-",0).astype('float')

# %%
ax = dados.plot(x='Unidade da Federação', 
                y=mes_mais_recente,
                kind='bar',
                figsize=(9,6))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}'))
plt.title("Valor gasto com internação no SIH/SUS por estado brasileiro de agosto de 2020")
plt.show()

# %% [markdown]
# Descrição gráfico
#
# * Título: Valor gasto com internação no SIH/SUS por estado brasileiro de agosto de 2020
# * Base de dados utilizada: Variável dados
# * Tipo de gráfico: Barras
# * Eixo X: Estados
# * Eixo Y: Valores de julho de 2020
# * O que está sendo mostrado: Foi criado um gráfico de barra dos 26 Estados Brasileiros mais o Distrito Federal relacionando ao seu custo por internação referente ao mês de Julho de 2020 com a correção da escala de valores no eixo Y descrito em milhões alterada de 0 até duzentos e cinquenta milhões, título mais descritivo.
#
# Mesmo com 12 anos de diferença a proporção se mantem semelhante, São Paulo diminuiu 35 milhões em 12 anos, população cresceu em 12 anos e estamos em uma pandemia, ainda assim os gastos são menores.

# %% [markdown]
# Texto

# %% [markdown]
# ## Aula 2

# %%
#selecionando duas colunas
dados[["2008/Ago", "2008/Set"]].head()
# Out:
#        2008/Ago      2008/Set
# 0  2,938,286.29  2,843,930.91
# 1  1,886,871.84  2,084,884.80
# 2  8,331,763.97  8,148,089.92
# 3  1,045,291.11  1,003,740.89
# 4 23,259,148.28 23,667,690.01

# %%
dados.mean() # média das colunas
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# 2007/Ago         304,952.77
# 2007/Set         788,145.26
# 2007/Out       2,440,162.96
# 2007/Nov       5,517,354.05
# 2007/Dez      12,337,159.42
#                  ...
# 2020/Mai      46,769,027.82
# 2020/Jun      45,367,349.74
# 2020/Jul      40,717,083.95
# 2020/Ago      19,144,523.30
# Total      5,993,724,452.01
# Length: 158, dtype: float64

# %%
colunas_usaveis = dados.mean().index
colunas_usaveis
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Index(['2007/Ago', '2007/Set', '2007/Out', '2007/Nov', '2007/Dez', '2008/Jan',
#        '2008/Fev', '2008/Mar', '2008/Abr', '2008/Mai',
#        ...
#        '2019/Dez', '2020/Jan', '2020/Fev', '2020/Mar', '2020/Abr', '2020/Mai',
#        '2020/Jun', '2020/Jul', '2020/Ago', 'Total'],
#       dtype='object', length=158)

# %%
dados[colunas_usaveis]
# Out:
#        2007/Ago     2007/Set  ...       2020/Ago             Total
# 0      4,209.37    16,397.03  ...   3,556,381.57    929,129,659.72
# 1     10,470.07    14,001.71  ...           0.00    420,668,039.63
# 2     35,752.72    45,570.64  ...   4,726,485.73  1,771,654,871.23
# 3      4,785.91    11,858.63  ...   1,524,478.04    305,010,883.18
# 4    181,159.29   433,414.74  ...  11,559,714.54  4,437,115,730.71
# 5     33,672.74   104,822.98  ...     834,187.31    291,637,984.75
# 6      4,113.76    76,633.06  ...   2,453,362.74    999,998,621.85
# 7    385,330.18 1,018,352.93  ...  10,916,718.78  3,632,860,959.84
# 8    220,788.25   353,468.67  ...   7,926,321.69  2,130,616,492.35
# 9    357,904.65   572,356.18  ...  14,559,529.59  6,197,357,245.98
# 10   134,605.36   272,088.08  ...   8,080,160.97  2,477,372,149.60
# 11    97,352.78   368,130.43  ...   8,585,226.08  2,470,550,104.25
# 12   400,640.85 1,088,340.42  ...  33,544,876.14  8,046,954,289.39
# ...

# %%
# Aqui utilizamos o mean para selecionar apenas as colunas numéricas e então
# salvamos uma lista com os nomes dessas colunas
colunas_usaveis = dados.mean().index.tolist()

# Agora adicionamos a coluna "Unidade da Federação" de volta à lista de das colunas
# filtradas acima (essa coluna ficou de fora por não ser numérica)
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
# ...

# %%
# Novo DataFrame a partir das coulnas identificadas
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação   2007/Ago  ...      2020/Ago            Total
# 0          11 Rondônia   4,209.37  ...  3,556,381.57   929,129,659.72
# 1              12 Acre  10,470.07  ...          0.00   420,668,039.63
# 2          13 Amazonas  35,752.72  ...  4,726,485.73 1,771,654,871.23
# 3           14 Roraima   4,785.91  ...  1,524,478.04   305,010,883.18
# 4              15 Pará 181,159.29  ... 11,559,714.54 4,437,115,730.71
#
# [5 rows x 159 columns]

# %%
# Utilizamos então o set_index para definir a coluna "Unidade da Federação" como o índice do DataFrame
usaveis = usaveis.set_index("Unidade da Federação")
usaveis
# Out:
#                            2007/Ago  ...             Total
# Unidade da Federação                 ...
# 11 Rondônia                4,209.37  ...    929,129,659.72
# 12 Acre                   10,470.07  ...    420,668,039.63
# 13 Amazonas               35,752.72  ...  1,771,654,871.23
# 14 Roraima                 4,785.91  ...    305,010,883.18
# 15 Pará                  181,159.29  ...  4,437,115,730.71
# 16 Amapá                  33,672.74  ...    291,637,984.75
# 17 Tocantins               4,113.76  ...    999,998,621.85
# 21 Maranhão              385,330.18  ...  3,632,860,959.84
# 22 Piauí                 220,788.25  ...  2,130,616,492.35
# 23 Ceará                 357,904.65  ...  6,197,357,245.98
# 24 Rio Grande do Norte   134,605.36  ...  2,477,372,149.60
# 25 Paraíba                97,352.78  ...  2,470,550,104.25
# 26 Pernambuco            400,640.85  ...  8,046,954,289.39
# 27 Alagoas               104,243.75  ...  2,104,405,303.11
# ...

# %%
usaveis["2019/Ago"]
# Out:
# Unidade da Federação
# 11 Rondônia                8,909,111.89
# 12 Acre                    2,981,072.98
# 13 Amazonas               16,493,719.52
# 14 Roraima                 3,181,321.82
# 15 Pará                   36,462,011.47
# 16 Amapá                   2,173,060.89
# 17 Tocantins               7,140,062.79
# 21 Maranhão               31,374,191.37
# 22 Piauí                  17,816,404.11
# 23 Ceará                  51,672,585.01
# 24 Rio Grande do Norte    23,073,307.72
# 25 Paraíba                19,854,699.54
# 26 Pernambuco             71,735,626.96
# 27 Alagoas                17,668,105.59
# 28 Sergipe                10,075,280.52
# 29 Bahia                  77,852,441.31
# 31 Minas Gerais          161,707,825.05
# 32 Espírito Santo         29,298,721.79
# 33 Rio de Janeiro         83,311,603.59
# 35 São Paulo             302,367,276.77
# 41 Paraná                127,174,095.05
# 42 Santa Catarina         64,503,540.72
# 43 Rio Grande do Sul      98,546,110.10
# ...

# %%
# O loc pode ser utilizado para buscar uma linha a partir do seu índice
usaveis.loc["12 Acre"]
# Out:
# 2007/Ago        10,470.07
# 2007/Set        14,001.71
# 2007/Out        86,200.85
# 2007/Nov       301,323.68
# 2007/Dez       769,612.36
#                 ...
# 2020/Mai     2,383,895.48
# 2020/Jun     2,199,920.70
# 2020/Jul     1,163,813.08
# 2020/Ago             0.00
# Total      420,668,039.63
# Name: 12 Acre, Length: 158, dtype: float64

# %%
usaveis.plot(figsize=(12,6))

# %% [markdown]
# Descrição gráfico
#
# * Título: Sem título
# * Base de dados utilizada: Variável usaveis
# * Tipo de gráfico: Linha
# * Eixo X: Estado
# * Eixo Y: Valores de todos os meses de ago/2007 até jul/2020 e o total
# * O que está sendo mostrado: Foi criado um gráfico de linha dos 26 Estados Brasileiros mais o Distrito Federal relacionando ao seu custo por internação referente ao mês de agosto de 2007 até julho de 2020, retirando as colunas que não possuiam dados preenchidos. É possível observar uma legenda que sobrepos o gráfico e conta com todos os meses analisados.

# %%
usaveis.head()
# Out:
#                        2007/Ago   2007/Set  ...      2020/Ago            Total
# Unidade da Federação                        ...
# 11 Rondônia            4,209.37  16,397.03  ...  3,556,381.57   929,129,659.72
# 12 Acre               10,470.07  14,001.71  ...          0.00   420,668,039.63
# 13 Amazonas           35,752.72  45,570.64  ...  4,726,485.73 1,771,654,871.23
# 14 Roraima             4,785.91  11,858.63  ...  1,524,478.04   305,010,883.18
# 15 Pará              181,159.29 433,414.74  ... 11,559,714.54 4,437,115,730.71
#
# [5 rows x 158 columns]

# %%
# Utilizamos o "T" para "girar" ou transpor, o DataFrame, cada linha se torna uma coluna
usaveis.T
# Out:
# Unidade da Federação    11 Rondônia  ...  53 Distrito Federal
# 2007/Ago                   4,209.37  ...           191,951.47
# 2007/Set                  16,397.03  ...           769,966.25
# 2007/Out                 133,645.19  ...         2,165,619.56
# 2007/Nov                 346,912.84  ...         3,813,256.48
# 2007/Dez                 711,758.31  ...         7,121,965.42
# ...                             ...  ...                  ...
# 2020/Mai               8,581,195.13  ...        21,437,430.22
# 2020/Jun               9,193,593.76  ...        23,479,773.03
# 2020/Jul               7,407,388.24  ...        22,233,542.26
# 2020/Ago               3,556,381.57  ...        12,044,848.02
# Total                929,129,659.72  ...     2,429,933,198.76
#
# [158 rows x 27 columns]

# %%
usaveis.T.tail()
# Out:
# Unidade da Federação    11 Rondônia  ...  53 Distrito Federal
# 2020/Mai               8,581,195.13  ...        21,437,430.22
# 2020/Jun               9,193,593.76  ...        23,479,773.03
# 2020/Jul               7,407,388.24  ...        22,233,542.26
# 2020/Ago               3,556,381.57  ...        12,044,848.02
# Total                929,129,659.72  ...     2,429,933,198.76
#
# [5 rows x 27 columns]

# %%
usaveis.T.plot(figsize=(12,6))

# %% [markdown]
# Descrição gráfico
# - Título: Sem título
# - Base de dados utilizada: Variável usaveis
# - Tipo de gráfico: Linha
# - Eixo X: Anos/meses
# - Eixo Y: Valores
# - O que está sendo mostrado: Foi feita a transposição do DataFrame usaveis e gerado o gráfico com os vinte e seis Estados Brasileiros e Distrito Federal aparecendo agora na legenda.

# %%
# Retirar coluna Total pois está distorcendo os dados
# com axis=1 estamos removendo uma coluna
usaveis = usaveis.drop("Total", axis=1)
usaveis.head()
# Out:
#                        2007/Ago   2007/Set  ...      2020/Jul      2020/Ago
# Unidade da Federação                        ...
# 11 Rondônia            4,209.37  16,397.03  ...  7,407,388.24  3,556,381.57
# 12 Acre               10,470.07  14,001.71  ...  1,163,813.08          0.00
# 13 Amazonas           35,752.72  45,570.64  ... 13,358,514.02  4,726,485.73
# 14 Roraima             4,785.91  11,858.63  ...  2,739,498.41  1,524,478.04
# 15 Pará              181,159.29 433,414.74  ... 27,618,727.51 11,559,714.54
#
# [5 rows x 157 columns]

# %%
usaveis.T.plot(figsize=(12,6))

# %% [markdown]
# Descrição gráfico
# - Título: Sem título
# - Base de dados utilizada: Variável usaveis
# - Tipo de gráfico: Linha
# - Eixo X: Anos/meses
# - Eixo Y: Valores
# - O que está sendo mostrado: Foi feito o drop da coluna total e a visualizaçào do gráfico foi alterada gerando um novo resultado em que podemos observar uma sazonalidade e crescimento. Contendo na legenda os vinte e seis estados brasileiros e o Distrito Fede

# %% [markdown]
# ## Desafios Aula 2

# %% [markdown]
# ## Desafio: reposicionar a legenda. Dentro? Fora? Onde?

# %%
usaveis.columns
# Out:
# Index(['2007/Ago', '2007/Set', '2007/Out', '2007/Nov', '2007/Dez', '2008/Jan',
#        '2008/Fev', '2008/Mar', '2008/Abr', '2008/Mai',
#        ...
#        '2019/Nov', '2019/Dez', '2020/Jan', '2020/Fev', '2020/Mar', '2020/Abr',
#        '2020/Mai', '2020/Jun', '2020/Jul', '2020/Ago'],
#       dtype='object', length=157)

# %%
# O .plot retona um objeto que representa os eixos do gráfico
# aqui salvamos esse objeto em ax para futuras configurações
ax = usaveis.T.plot(figsize=(12,6))

# A partir do ax configuramos a posição da legenda com o legend
ax.legend(loc='upper center', bbox_to_anchor=(0.5,-0.07), ncol=4) # upper center posicionar no meio e o bbox_to_anchor ajustar posição e ncol = número de colunas

plt.show()

# %% [markdown]
# ## Desafio: Mudar palete de cor com matplotlib

# %%
# Criação manual do palete de cores
color = ['#006BA4', '#FF800E', '#ABABAB', '#595959', '#5F9ED1', '#C85200', '#898989', '#A2C8EC', '#FFBC79', '#CFCFCF',
          '#AE0DDE', '#3B7D54', '#1540F5', '#5B8D51', '#966E83', '#603F43', '#EE4961', '#642C80', '#AD95C6', '#30D4F7',
          '#D83598', '#390C52', '#3AACCE', '#4EAABC', '#24C7AA', '#2C82F4', '#62AD3A']
len(color) #o comando len traz o comprimento total
# Out:
# 27

# %%
ax = usaveis.T.plot(figsize=(12,6), color=color)
ax.legend(loc='upper center', bbox_to_anchor=(0.5,-0.07), ncol=4) # upper center posicionar no meio e o bbox_to_anchor ajustar posição e ncol = número de colunas

plt.show()

# %% [markdown]
# Descrição gráfico
#
# - Título: Sem título
# - Base de dados utilizada: Variável usaveis
# - Tipo de gráfico: Linhas
# - Eixo X: Ano/mês
# - Eixo Y: Valores
# - O que está sendo mostrado: Ainda utilizando o gráfico anterior, fizemos a alteração da paleta de cores manualmente para todos os 26 Estados Brasileiros mais o Distrito Federal.

# %%
import numpy as np
from matplotlib import cm

color = cm.gist_rainbow(np.linspace(.0, 1, 27))

ax = usaveis.T.plot(figsize=(12,6), color=color)
ax.legend(loc='upper center', bbox_to_anchor=(0.5,-0.07), ncol=4)
plt.show()

# %% [markdown]
# Descrição gráfico
#
# - Título: Sem título
# - Base de dados utilizada: Variável usaveis
# - Tipo de gráfico: Linhas
# - Eixo X: Ano/mês
# - Eixo Y: Valores
# - O que está sendo mostrado: Ainda utilizando o gráfico anterior, fizemos a alteração da paleta de cores baseada em uma paleta disponível na biblioteca matplotlib para pessoas com daltonismo para todos os 26 Estados Brasileiros mais o Distrito Federal.

# %% [markdown]
# ## Aula 3

# %%
# Transpor planilha para index virar as colunas
usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  ...     52 Goiás  53 Distrito Federal
# 2007/Ago                 4,209.37  10,470.07  ...   179,395.82           191,951.47
# 2007/Set                16,397.03  14,001.71  ...   418,053.58           769,966.25
# 2007/Out               133,645.19  86,200.85  ... 1,198,730.25         2,165,619.56
# 2007/Nov               346,912.84 301,323.68  ... 2,712,117.54         3,813,256.48
# 2007/Dez               711,758.31 769,612.36  ... 9,293,914.78         7,121,965.42
#
# [5 rows x 27 columns]

# %%
#Selecionando os 5 primeiros (colunas)
usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
# Selecionando os 5 primeiros estados tb porém pelo indice
usaveis.index[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis[:5]
# Out:
#                        2007/Ago   2007/Set  ...      2020/Jul      2020/Ago
# Unidade da Federação                        ...
# 11 Rondônia            4,209.37  16,397.03  ...  7,407,388.24  3,556,381.57
# 12 Acre               10,470.07  14,001.71  ...  1,163,813.08          0.00
# 13 Amazonas           35,752.72  45,570.64  ... 13,358,514.02  4,726,485.73
# 14 Roraima             4,785.91  11,858.63  ...  2,739,498.41  1,524,478.04
# 15 Pará              181,159.29 433,414.74  ... 27,618,727.51 11,559,714.54
#
# [5 rows x 157 columns]

# %%
# Selecionado estados do Norte (Slice dos 7 primeiros "por sorte")
usaveis[:7].T.plot(figsize=(10,6))

# %%
# aleatorios
usaveis.sample(n=7)
# Out:
#                           2007/Ago     2007/Set  ...      2020/Jul      2020/Ago
# Unidade da Federação                             ...
# 21 Maranhão             385,330.18 1,018,352.93  ... 24,374,205.15 10,916,718.78
# 29 Bahia                135,146.36   448,349.75  ... 58,898,100.40 26,023,558.53
# 51 Mato Grosso           63,562.50   232,444.62  ... 13,083,151.70  6,174,224.99
# 50 Mato Grosso do Sul   199,556.12   573,675.41  ... 12,508,717.35  4,059,220.22
# 12 Acre                  10,470.07    14,001.71  ...  1,163,813.08          0.00
# 42 Santa Catarina       693,955.05 1,092,964.12  ... 51,764,534.76 16,991,236.43
# 43 Rio Grande do Sul  1,049,252.33 3,182,913.14  ... 78,929,703.81 28,349,257.38
#
# [7 rows x 157 columns]

# %%
# Utilizando a biblioteca numpy para definir o seed e reproduzir o mesmo resultado  
#aleatorios (porém com seed (semente para rodar a aleatoriedade) consegue repetir resultado)
import numpy as np
np.random.seed(687942)

# Amostra aleatória da base, n=7 usando sete elementos
usaveis.sample(n=7)
# Out:
#                          2007/Ago     2007/Set  ...       2020/Jul      2020/Ago
# Unidade da Federação                            ...
# 32 Espírito Santo       57,408.11   284,224.80  ...  27,460,475.47 10,824,255.26
# 31 Minas Gerais        971,394.37 2,861,781.50  ... 120,467,187.34 57,473,699.06
# 24 Rio Grande do Norte 134,605.36   272,088.08  ...  19,593,057.45  8,080,160.97
# 17 Tocantins             4,113.76    76,633.06  ...   4,489,665.87  2,453,362.74
# 53 Distrito Federal    191,951.47   769,966.25  ...  22,233,542.26 12,044,848.02
# 50 Mato Grosso do Sul  199,556.12   573,675.41  ...  12,508,717.35  4,059,220.22
# 16 Amapá                33,672.74   104,822.98  ...   2,155,083.37    834,187.31
#
# [7 rows x 157 columns]

# %%
usaveis.sample(n=7)
# Out:
#                          2007/Ago     2007/Set  ...       2020/Jul       2020/Ago
# Unidade da Federação                            ...
# 42 Santa Catarina      693,955.05 1,092,964.12  ...  51,764,534.76  16,991,236.43
# 33 Rio de Janeiro      469,469.34   921,646.57  ...  71,540,227.33  36,264,322.65
# 31 Minas Gerais        971,394.37 2,861,781.50  ... 120,467,187.34  57,473,699.06
# 35 São Paulo         1,665,349.90 4,434,168.64  ... 282,709,570.31 140,414,944.95
# 21 Maranhão            385,330.18 1,018,352.93  ...  24,374,205.15  10,916,718.78
# 52 Goiás               179,395.82   418,053.58  ...  33,499,284.38  20,242,641.73
# 32 Espírito Santo       57,408.11   284,224.80  ...  27,460,475.47  10,824,255.26
#
# [7 rows x 157 columns]

# %%
# ideia de como funciona aleatoriedade
# pseudo randomness

# seed = 6987
# random = seed / 10, seed = seed * 2 /3


# random ===> 698...... (seed=4658)
# random ==> 465 (seed = 310)
# random ==> 31

# %%
usaveis.sum(axis=1)
# Out:
# Unidade da Federação
# 11 Rondônia                 929,129,055.39
# 12 Acre                     420,666,755.81
# 13 Amazonas               1,771,652,039.82
# 14 Roraima                  305,010,469.49
# 15 Pará                   4,437,097,195.11
# 16 Amapá                    291,615,887.03
# 17 Tocantins                999,960,604.09
# 21 Maranhão               3,632,801,824.38
# 22 Piauí                  2,130,602,528.98
# 23 Ceará                  6,197,345,931.63
# 24 Rio Grande do Norte    2,477,315,927.36
# 25 Paraíba                2,470,526,884.71
# 26 Pernambuco             8,046,679,981.91
# 27 Alagoas                2,104,391,371.86
# 28 Sergipe                1,130,327,450.81
# 29 Bahia                  9,193,757,249.74
# 31 Minas Gerais          19,159,574,431.00
# 32 Espírito Santo         3,139,177,454.95
# 33 Rio de Janeiro         9,696,202,329.77
# 35 São Paulo             38,919,478,583.07
# 41 Paraná                13,786,791,386.76
# ...

# %%
# adicionando coluna Total
usaveis["Total"] = usaveis.sum(axis=1)
usaveis.head()
# Out:
#                        2007/Ago   2007/Set  ...      2020/Ago            Total
# Unidade da Federação                        ...
# 11 Rondônia            4,209.37  16,397.03  ...  3,556,381.57   929,129,055.39
# 12 Acre               10,470.07  14,001.71  ...          0.00   420,666,755.81
# 13 Amazonas           35,752.72  45,570.64  ...  4,726,485.73 1,771,652,039.82
# 14 Roraima             4,785.91  11,858.63  ...  1,524,478.04   305,010,469.49
# 15 Pará              181,159.29 433,414.74  ... 11,559,714.54 4,437,097,195.11
#
# [5 rows x 158 columns]

# %% [markdown]
# ## Desafio: adicionar uma coluna mostrando a região de cada estado

# %%
# adição manual usando uma lista
usaveis["Regioes"] = ['Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Norte', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Nordeste', 'Sudeste', 'Sudeste', 'Sudeste', 'Sudeste', 'Sul', 'Sul', 'Sul', 'Centro-Oeste','Centro-Oeste','Centro-Oeste','Centro-Oeste']

# %%
usaveis.index
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
# Versão simplificada por quantidade de estados
# usaveis["Regioes"] = ["Norte"] * 7 + ["Nordeste"] * 9 + ["Sudeste"] * 4 + ["Sul"] * 3 + ["Centro_Oeste"] * 4

# %%
usaveis["Regioes"]
# Out:
# Unidade da Federação
# 11 Rondônia                      Norte
# 12 Acre                          Norte
# 13 Amazonas                      Norte
# 14 Roraima                       Norte
# 15 Pará                          Norte
# 16 Amapá                         Norte
# 17 Tocantins                     Norte
# 21 Maranhão                   Nordeste
# 22 Piauí                      Nordeste
# 23 Ceará                      Nordeste
# 24 Rio Grande do Norte        Nordeste
# 25 Paraíba                    Nordeste
# 26 Pernambuco                 Nordeste
# 27 Alagoas                    Nordeste
# 28 Sergipe                    Nordeste
# 29 Bahia                      Nordeste
# 31 Minas Gerais                Sudeste
# 32 Espírito Santo              Sudeste
# 33 Rio de Janeiro              Sudeste
# 35 São Paulo                   Sudeste
# 41 Paraná                          Sul
# 42 Santa Catarina                  Sul
# 43 Rio Grande do Sul               Sul
# ...

# %%
# Ordenado por região em ordem alfabética crescente
ordenado_por_regiao = usaveis.sort_values("Regioes", ascending=True)
ordenado_por_regiao
# Out:
#                            2007/Ago  ...       Regioes
# Unidade da Federação                 ...
# 53 Distrito Federal      191,951.47  ...  Centro-Oeste
# 51 Mato Grosso            63,562.50  ...  Centro-Oeste
# 50 Mato Grosso do Sul    199,556.12  ...  Centro-Oeste
# 52 Goiás                 179,395.82  ...  Centro-Oeste
# 29 Bahia                 135,146.36  ...      Nordeste
# 28 Sergipe                27,453.63  ...      Nordeste
# 26 Pernambuco            400,640.85  ...      Nordeste
# 25 Paraíba                97,352.78  ...      Nordeste
# 24 Rio Grande do Norte   134,605.36  ...      Nordeste
# 27 Alagoas               104,243.75  ...      Nordeste
# 22 Piauí                 220,788.25  ...      Nordeste
# 21 Maranhão              385,330.18  ...      Nordeste
# 23 Ceará                 357,904.65  ...      Nordeste
# 12 Acre                   10,470.07  ...         Norte
# 13 Amazonas               35,752.72  ...         Norte
# ...

# %%
# Agrupado Total dos estados por região em ordem do maior para menor
total_por_regiao = usaveis.groupby(["Regioes"]).sum()
total_por_regiao_desc = total_por_regiao.sort_values("Total", ascending=False)
total_por_regiao_desc["Total"]
# Out:
# Regioes
# Sudeste        70,914,432,798.79
# Nordeste       37,383,749,151.38
# Sul            33,069,282,684.06
# Centro-Oeste   11,296,163,195.17
# Norte           9,155,132,006.74
# Name: Total, dtype: float64

# %% [markdown]
# Cont... Aula 3

# %%
# Ordenado por total decrescente
ordenado_por_total = usaveis.sort_values("Total", ascending=False)
# Retirado/Drop total para não distorcer graficos e manter como anteriormente
ordenado_por_total = ordenado_por_total.drop("Total", axis=1)
# REtirado/Drop total por região para plotar próximos graficos
ordenado_por_total = ordenado_por_total.drop("Regioes", axis=1)
ordenado_por_total.head()
# Out:
#                          2007/Ago     2007/Set  ...       2020/Jul       2020/Ago
# Unidade da Federação                            ...
# 35 São Paulo         1,665,349.90 4,434,168.64  ... 282,709,570.31 140,414,944.95
# 31 Minas Gerais        971,394.37 2,861,781.50  ... 120,467,187.34  57,473,699.06
# 41 Paraná              554,800.22 1,431,708.01  ...  80,320,852.69  41,542,401.16
# 43 Rio Grande do Sul 1,049,252.33 3,182,913.14  ...  78,929,703.81  28,349,257.38
# 33 Rio de Janeiro      469,469.34   921,646.57  ...  71,540,227.33  36,264,322.65
#
# [5 rows x 157 columns]

# %%
ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %% [markdown]
# Final da aula 3

# %% [markdown]
# ## Desafio: deixar o grafico mais bonito, mensagem mais clara

# %%
ax = ordenado_por_total.head(5).T.plot(figsize=(10,6))
ax.legend(loc='best', bbox_to_anchor=(1, 1))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.0f}"))
# Título
plt.title("Gasto total com internações no SIH/SUS dos 5 Estados Brasileiros que mais gastaram")
# Ajuste legenda Eixo X com rotação em 45 graus
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

plt.show()

# %% [markdown]
# Descrição gráfico
#
# - Título: Gasto total com internações no SIH/SUS dos 5 Estados Brasileiros que mais gastaram
# - Base de dados utilizada: Variável ordenado_por_total
# - Tipo de gráfico: Linha
# - Eixo X: Ano/Mês
# - Eixo Y: Valores
# O que está sendo mostrado: Podemos observar os cinco Estados com maiores gastos compreendidos entre agosto de 2007 e abril de 2019. Em ordem crescente temos: Rio de Janeiro, Rio Grande do Sul, Paraná, Minas Gerais e por último com o maior gasto o Estado de São Paulo.

# %%
ax = ordenado_por_total.head(5).T.plot(figsize=(10,6))

ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))

plt.title("Gráfico dos cinco maiores gastos referente a internações no SUS de 2008 à 2019") 
plt.ylim(0, 350000000)

plt.show()

# %% [markdown]
# Descrição gráfico
#
# - Título: Gráfico dos cinco maiores gastos referente a internações no SUS de 2008 à 2019
# - Base de dados utilizada: Variável ordenado_por_total
# - Tipo de gráfico: Linha
# - Eixo X: Ano/Mês
# - Eixo Y: Valores
# - O que está sendo mostrado: Ainda baseado no gráfico anterior, foi adequado a escala de valores e fixado o intervalo do eixo y de 0 à 350 milhões e adicionado título descritivo, analisando os Estados São Paulo, Minas Gerais, Paraná, Rio Grande do Sul e Rio de Janeiro

# %% [markdown]
# Análise do gráfico:
#
# Podemos observar no gráfico uma sazonalidade além de um quadro de crescimento em todos os Estados. Observamos os valores iniciando próximos a escala de cinquenta milhões com o Estado do Rio de Janeiro, Rio Grande do Sul e Paraná, depois podemos observar Minas Gerais já avançando com gastos que passam cem milhões e o Estado de São Paulo que é o mais distante em gastos, iniciando em cento e setenta e dois milhões no ano de 2008 e em 2019 no mês de outubro chega em duzentos e setenta e dois milhões, enquanto os demais estados não ultrapassam os cento e cinquenta milhões.

# %% [markdown]
# ## Desafio: adicione o seu estado ou outro aos 5 estados existentes e plote

# %%
# Transformar head em lista
top_5 = list(ordenado_por_total.head(5).index)
# adicionar estado a lista anterior
top_5_mais_SC = top_5 + ['42 Santa Catarina']
top_5_mais_SC
# Out:
# ['35 São Paulo',
#  '31 Minas Gerais',
#  '41 Paraná',
#  '43 Rio Grande do Sul',
#  '33 Rio de Janeiro',
#  '42 Santa Catarina']

# %%
ax = ordenado_por_total.T[top_5_mais_SC].plot(figsize=(10,6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))

# %% [markdown]
# Descrição gráfico
#
# - Título: Sem título
# - Base de dados utilizada: ordenado_por_total
# - Tipo de gráfico: Linha
# - Eixo X: Ano/Mês
# - Eixo Y: Valores
# - O que está sendo mostrado: Foi adicionado ao gráfico o Distrito Federal para análise junto dos 5 maiores custos totais entre os Estados Brasileiros, São Paulo, Minas Gerais, Paraná, Rio Grande do Sul e Rio de Janeiro respectivamente do maior para o menor.

# %% [markdown]
# **Continuação da Aula 3**

# %%
ordenado_por_total = usaveis.sort_values("Total", ascending=False)
ordenado_por_total = ordenado_por_total.drop(["Total", "Regioes"], axis=1)
ordenado_por_total.head(2)
# Out:
#                          2007/Ago     2007/Set  ...       2020/Jul       2020/Ago
# Unidade da Federação                            ...
# 35 São Paulo         1,665,349.90 4,434,168.64  ... 282,709,570.31 140,414,944.95
# 31 Minas Gerais        971,394.37 2,861,781.50  ... 120,467,187.34  57,473,699.06
#
# [2 rows x 157 columns]

# %%
# usaveis = usaveis.drop(["Total", "Regioes"], axis=1)
# usaveis[:7].T.plot(figsize=(10,6))

# %%
ordenado_por_total.head(5).T.plot(figsize=(10,6))

# %%
# Slice trazendo os resultados do índice 6 para frente (após data com pico) para uma mlehor visualização
colunas_interessadas = ordenado_por_total.columns[6:]
ordenado_por_total = ordenado_por_total[colunas_interessadas]

# %%
ax = ordenado_por_total.head(5).T.plot(figsize=(10, 6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))

# %% [markdown]
# Descrição gráfico
#
# - Título: Sem título
# - Base de dados utilizada: Variável ordenada_por_total
# - Tipo de gráfico: Linha
# - Eixo X: Ano/Mês
# - Eixo Y: Valores
# - O que está sendo mostrado: Neste gráfico foram retirados os primeiros seis meses da base de dados, pois encontravam-se sem informações preenchidas, além do primeiro mês que contava com valores iniciais discrepantes que geravam ruído, analisando os Estados São Paulo, Minas Gerais, Paraná, Rio Grande do Sul e Rio de Janeiro.

# %% [markdown]
# ## Desafio: googlar os casos de dengue no Brasil e ver se reflete nos gastos

# %% [markdown]
# 2008 junho - Dengue Rio de Janeiro 249.743 casos, sendo abril 102.031 fonte http://www.cives.ufrj.br/informacao/dengue/den-Rio2008.html
# 2010 novembro - Dengue na região Sudeste registrou 473.994 fonte http://g1.globo.com/luta-contra-a-dengue/noticia/2011/02/notificacoes-de-dengue-mais-que-triplicam-em-2010-aponta-ministerio.html
# 2011 janeiro - Dengue aumentou em 58,9% no Rio de Janeiro fonte http://g1.globo.com/ciencia-e-saude/noticia/2011/07/dengue-causou-310-mortes-no-1-semestre-deste-ano-no-pais.html
# 2013 janeiro - Dengue aumentou em 190% no País fonte http://g1.globo.com/bemestar/noticia/2013/02/casos-de-dengue-no-pais-aumentam-190-no-comeco-de-2013-diz-governo.html
# 2016 junho - Dengue teve quase 1,5 milhão de casos de dengue fonte https://g1.globo.com/bemestar/noticia/2016-ja-teve-mais-de-19-milhao-de-casos-de-dengue-chikungunya-e-zika.ghtml

# %% [markdown]
# Primeiro analisamos se tinha relação com as ferias porem o aumento não acontecia no meses de junho e julho, então a hipotese dos picos de internação serem gerados por conta da dengue trazem a possibilidade conforme fontes.

# %% [markdown]
# ## Desafio: plotar só os estados do sudeste e ver se afetou com um pico em 2012/2013 de forma similar esses estados

# %%
usaveis.columns
# Out:
# Index(['2007/Ago', '2007/Set', '2007/Out', '2007/Nov', '2007/Dez', '2008/Jan',
#        '2008/Fev', '2008/Mar', '2008/Abr', '2008/Mai',
#        ...
#        '2020/Jan', '2020/Fev', '2020/Mar', '2020/Abr', '2020/Mai', '2020/Jun',
#        '2020/Jul', '2020/Ago', 'Total', 'Regioes'],
#       dtype='object', length=159)

# %%
ax = usaveis.query("Regioes == 'Sudeste'").drop(["Total", "Regioes"], axis=1).T.iloc[6:].plot(figsize=(10, 6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Gráfico dos cinco maiores gastos referente a internações no SUS de 2008 à 2019") 


plt.show()

# %% [markdown]
# ## Desafio: adicionar seu estado escolhido novamente e deixe o gráfico lindo com informações claras

# %%
ax = ordenado_por_total.T[top_5_mais_SC].plot(figsize=(10, 6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Gráfico dos cinco maiores gastos mais Santa Catarina referente a internações no SUS de 2008 à 2019") 
plt.ylim(0, 350000000)

plt.show()

# %% [markdown]
# Descrição gráfico
#
# - Título: Gráfico dos cinco maiores gastos mais Santa Catarina referente a internações no SUS de 2008 à 2019
# - Base de dados utilizada: Variável ordenado_por_total
# - Tipo de gráfico: Linha
# - Eixo X: Ano/Mês
# - Eixo Y: Valores
# - O que está sendo mostrado: Neste gráfico foi adicionado um Estado a nossa escolha, Santa Catarina, ao top cinco Estados com maiores gastos, São Paulo, Minas Gerais, Paraná, Rio Grande do Sul e Rio de Janeiro.

# %% [markdown]
# fim aula 3 modulo 1

# %% [markdown]
# ## Aula 4 - módulo 1

# %%
ordenado_por_total = ordenado_por_total / 1000000 #Divisão para milhào para facilitar a visualização
ax = ordenado_por_total.head(5).T.plot(figsize=(10,6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))

# %% [markdown]
# Descrição gráfico
#
# * Título: Sem título
# *Base de dados utilizada: Variável ordenado_por_total
# *Tipo de gráfico: Linha
# *Eixo X: Ano/Mês
# *Eixo Y: Valores
# *O que está sendo mostrado: No gráfico foi alterada a escala do eixo Y para melhor visualização, sabendo que os dados estão na casa dos milhões. Observamos os cinco maiores gastos entre São Paulo, Minas Gerais, Paraná, Rio Grande do Sul e Rio de Janeiro.

# %% [markdown]
# Descrição gráfico
#
# - Título: Sem título
# - Base de dados utilizada: Variável ordenado_por_total
# - Tipo de gráfico: Linha
# - Eixo X: Ano/Mês
# - Eixo Y: Valores
# - O que está sendo mostrado: No gráfico foi alterada a escala do eixo Y para melhor visualização, sabendo que os dados estão na casa dos milhões. Observamos os cinco maiores gastos entre São Paulo, Minas Gerais, Paraná, Rio Grande do Sul e Rio de Janeiro.

# %%
# Filtrar meses
meses_filtrados = ordenado_por_total.columns[47:150] 
ax = ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))

# %% [markdown]
# Descrição gráfico
#
# - Título: Sem título
# - Base de dados utilizada: Variável ordenado_por_total
# - Tipo de gráfico: Linha
# - Eixo X: Ano/Mês
# - Eixo Y: Valores
# - O que está sendo mostrado: Nesse gráfico foi levantada a comparação direta de gastos entre os Estados São Paulo, Minas Gerais e Paraná, pois a impressão visualmente falando é que existe uma diferença entre eles maior do que são na verdade. É possível observar que São Paulo possui gastos quase três vezes maiores, porém, se observarmos apenas o visual, a tendência é acreditar que essa diferença chega a ser até seis vezes maior entre Paraná e São Paulo. A escala do gráfico inicia em 100 e vai até 300 milhões.

# %%
# Ajuste do Eixo Y com iniciando em Zero para refletir a realidade, principalmente ao comparar a relaçnao entre linhas
ax = ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %% [markdown]
# Descrição gráfico
#
# - Título: Sem título
# - Base de dados utilizada: Variável ordenado_por_total
# - Tipo de gráfico: Linha
# - Eixo X: Ano/Mês
# - Eixo Y: Valores
# - O que está sendo mostrado: Agora alteramos a escala iniciando em zero e indo até trezentos e cinquenta milhões, e agora a percepção de diferença entre os Estados de Paraná e São Paulo visualmente, parecem menores.

# %%
ax = ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))
plt.ylim(100, 350)
# Out:
# (100.0, 350.0)

# %% [markdown]
# Descrição gráfico
#
# * Título: Sem título
# *Base de dados utilizada: Variável ordenado_por_total
# *Tipo de gráfico: Linha
# *Eixo X: Ano/Mês
# *Eixo Y: Valores
# *O que está sendo mostrado: Neste gráfico voltamos a visualizar os dados com a escala entre cem e trezentos e cinquenta milhões, de forma que dificulta a percepção real já que existem valores omitidos no gráfico. O período analisado vai de janeiro de 2012 à maio de 2020.

# %%
# Últimos 12 meses
ax = ordenado_por_total[ordenado_por_total.columns[-12:]].head(3).T.plot(figsize=(10,6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %% [markdown]
# Descrição gráfico
#
# * Título: Sem título
# - Base de dados utilizada: Variável ordenado_por_total
# - Tipo de gráfico: Linha
# - Eixo X: Ano/Mês
# - Eixo Y: Valores
# - O que está sendo mostrado: Neste gráfico voltamos a visualizar os dados com a escala entre zero e trezentos e cinquenta milhões, porém, o período selecionado está entre agosto de 2019 e junho de 2020, tornando a visualização dos dados mais linear ou reta, dificultando a análise.

# %%
# Últimos 24 meses
ax = ordenado_por_total[ordenado_por_total.columns[-24:]].head(3).T.plot(figsize=(10,6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %% [markdown]
# Descrição gráfico
#
# * Título: Sem título
# *Base de dados utilizada: Variável ordenado_por_total
# *Tipo de gráfico: Linha
# *Eixo X: Ano/Mês
# *Eixo Y: Valores
# *O que está sendo mostrado: Neste gráfico foi selecionado outro intervalo para indicar erros possíveis de acontecer se não nos atentarmos aos detalhes, como por exemplo, ao observar no gráfico uma tendência decrescente nesse período entre agosto de 2018 e abril de 2020, levando a falsas análises.

# %%
# Últimos 36 meses
ax = ordenado_por_total[ordenado_por_total.columns[-36:]].head(3).T.plot(figsize=(10,6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %% [markdown]
# Descrição gráfico
#
# * Título: Sem título
# *Base de dados utilizada: Variável ordenado_por_total
# *Tipo de gráfico: Linha
# *Eixo X: Ano/Mês
# *Eixo Y: Valores
# *O que está sendo mostrado: Neste gráfico foi mostrado levemente a tendência de crescimento nos números totais.

# %%
ax = ordenado_por_total[ordenado_por_total.columns[-60:]].head(3).T.plot(figsize=(10,6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %% [markdown]
# Descrição gráfico
#
# * Título: Sem título
# *Base de dados utilizada: Variável ordenado_por_total
# *Tipo de gráfico: Linha
# *Eixo X: Ano/Mês
# *Eixo Y: Valores
# *O que está sendo mostrado: Neste gráfico foi mostrado a tendência de crescimento existente nos nossos dados.

# %% [markdown]
# **Mudar o recorte dos eixos nao mostra a realidade CUIDADO!**

# %%
ax = ordenado_por_total.head(5).T.plot(figsize=(10,6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))

# %% [markdown]
# Descrição gráfico
#
# * Título: Sem título
# *Base de dados utilizada: Variável ordenado_por_total
# *Tipo de gráfico: Linha
# *Eixo X: Ano/Mês
# *Eixo Y: Valores
# *O que está sendo mostrado: Este gráfico foi plotado novamente à mérito de comparação com as análises feitas nos gráficos anteriores e para validação de que existe uma sazonalidade além de uma tendência de crescimento observada.

# %%
ax = ordenado_por_total.head(5).T.plot(figsize=(6,6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))

# %% [markdown]
# Descrição gráfico
#
# * Título: Sem título
# *Base de dados utilizada: Variável ordenado_por_total
# *Tipo de gráfico: Linha
# *Eixo X: Ano/Mês
# *Eixo Y: Valores
# *O que está sendo mostrado: Este gráfico foi plotado novamente alterando o figsize para visualizarmos a possível impressão errada na análise que é gerada, conforme a inclinação das linhas.

# %%
ax = ordenado_por_total.head(5).T.plot(figsize=(20,6))
ax.legend(loc='best', bbox_to_anchor=(1.3, 1))

# %% [markdown]
# Descrição gráfico
#
# *Título: Sem título
# *Base de dados utilizada: Variável ordenado_por_total
# *Tipo de gráfico: Linha
# *Eixo X: Ano/Mês
# *Eixo Y: Valores
# *O que está sendo mostrado: Neste gráfico foi plotado alterando o figsize, esticando o gráfico lateralmente, dando a impressão de uma inclinação menor, um crescimento mais lento.

# %% [markdown]
# ## Aula 5 - módulo 1

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = ordenado_por_total.head(5).T.plot(figsize=(20,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:.2f}'))
plt.title("Valor gasto em procedimentos hospitalares (SUS) por unidade de federação")

plt.show()

# %% [markdown]
# Aula 5

# %%
mes_mais_recente = ordenado_por_total.columns[-1]

# %%
mes_mais_recente
# Out:
# '2020/Ago'

# %%
gastos_do_mes_mais_recente = ordenado_por_total[mes_mais_recente]
gastos_do_mes_mais_recente.head()
# Out:
# Unidade da Federação
# 35 São Paulo           140.41
# 31 Minas Gerais         57.47
# 41 Paraná               41.54
# 43 Rio Grande do Sul    28.35
# 33 Rio de Janeiro       36.26
# Name: 2020/Ago, dtype: float64

# %%
gastos_do_mes_mais_recente.plot()

# %%
gastos_do_mes_mais_recente.plot(kind='pie') # grafico pizza

# %% [markdown]
# Horrores do grafico de pizza:
# - legenda está horível
# - numero de fatias inacreditavel
#
# Já estamos com uma vanagem
# - o gráfico está ordenado

# %%
# sample aleatorio
gastos_do_mes_mais_recente.sample(frac=1)
# Out:
# Unidade da Federação
# 28 Sergipe                 1.74
# 27 Alagoas                 6.49
# 43 Rio Grande do Sul      28.35
# 14 Roraima                 1.52
# 51 Mato Grosso             6.17
# 21 Maranhão               10.92
# 11 Rondônia                3.56
# 26 Pernambuco             33.54
# 15 Pará                   11.56
# 12 Acre                    0.00
# 52 Goiás                  20.24
# 13 Amazonas                4.73
# 50 Mato Grosso do Sul      4.06
# 31 Minas Gerais           57.47
# 16 Amapá                   0.83
# 33 Rio de Janeiro         36.26
# 25 Paraíba                 8.59
# 32 Espírito Santo         10.82
# 29 Bahia                  26.02
# 24 Rio Grande do Norte     8.08
# 17 Tocantins               2.45
# 42 Santa Catarina         16.99
# 35 São Paulo             140.41
# 53 Distrito Federal       12.04
# 22 Piauí                   7.93
# 41 Paraná                 41.54
# 23 Ceará                  14.56
# Name: 2020/Ago, dtype: float64

# %%
gastos_do_mes_mais_recente.sample(frac=1).plot(kind='pie') # ordem aleatória

# %% [markdown]
# Horrores do grafico de pizza:
# - legenda está horível
# - numero de fatias inacreditavel
# - não da para saber a ordem
# - cores repetidas
# - muito ruim para definir ordem
# - pessimo COMPARAR

# %%
# visualização simpes para valor absoluto

gastos_do_mes_mais_recente
# Out:
# Unidade da Federação
# 35 São Paulo             140.41
# 31 Minas Gerais           57.47
# 41 Paraná                 41.54
# 43 Rio Grande do Sul      28.35
# 33 Rio de Janeiro         36.26
# 29 Bahia                  26.02
# 26 Pernambuco             33.54
# 42 Santa Catarina         16.99
# 23 Ceará                  14.56
# 52 Goiás                  20.24
# 15 Pará                   11.56
# 21 Maranhão               10.92
# 32 Espírito Santo         10.82
# 24 Rio Grande do Norte     8.08
# 25 Paraíba                 8.59
# 53 Distrito Federal       12.04
# 50 Mato Grosso do Sul      4.06
# 22 Piauí                   7.93
# 27 Alagoas                 6.49
# 51 Mato Grosso             6.17
# 13 Amazonas                4.73
# 28 Sergipe                 1.74
# 17 Tocantins               2.45
# 11 Rondônia                3.56
# 12 Acre                    0.00
# 14 Roraima                 1.52
# 16 Amapá                   0.83
# Name: 2020/Ago, dtype: float64

# %%
gastos_do_mes_mais_recente / gastos_do_mes_mais_recente.loc["33 Rio de Janeiro"]
# Out:
# Unidade da Federação
# 35 São Paulo             3.87
# 31 Minas Gerais          1.58
# 41 Paraná                1.15
# 43 Rio Grande do Sul     0.78
# 33 Rio de Janeiro        1.00
# 29 Bahia                 0.72
# 26 Pernambuco            0.93
# 42 Santa Catarina        0.47
# 23 Ceará                 0.40
# 52 Goiás                 0.56
# 15 Pará                  0.32
# 21 Maranhão              0.30
# 32 Espírito Santo        0.30
# 24 Rio Grande do Norte   0.22
# 25 Paraíba               0.24
# 53 Distrito Federal      0.33
# 50 Mato Grosso do Sul    0.11
# 22 Piauí                 0.22
# 27 Alagoas               0.18
# 51 Mato Grosso           0.17
# 13 Amazonas              0.13
# 28 Sergipe               0.05
# 17 Tocantins             0.07
# 11 Rondônia              0.10
# 12 Acre                  0.00
# 14 Roraima               0.04
# 16 Amapá                 0.02
# Name: 2020/Ago, dtype: float64

# %% [markdown]
# ## Desafio:  Criar tabela de comparação com o seu estado ou de  preferência

# %%
(gastos_do_mes_mais_recente / gastos_do_mes_mais_recente.loc["33 Rio de Janeiro"]).head(5)
# Out:
# Unidade da Federação
# 35 São Paulo           3.87
# 31 Minas Gerais        1.58
# 41 Paraná              1.15
# 43 Rio Grande do Sul   0.78
# 33 Rio de Janeiro      1.00
# Name: 2020/Ago, dtype: float64

# %%
(gastos_do_mes_mais_recente / gastos_do_mes_mais_recente.loc["33 Rio de Janeiro"]).plot(kind='bar')

# %% [markdown]
# ## Desafio: documentaçnao do matplotlib e pandas para colocar grid no gráfico

# %%
# ordenar usando sort values
gastos_do_mes_mais_recente = gastos_do_mes_mais_recente.sort_values(ascending=False)
gastos_do_mes_mais_recente.plot(kind='bar', grid=True)

# %% [markdown]
# ## Desafio: gráfico de barra do gasto dos outros estados em função ao seu estado

# %%
gastos_recente_em_funcao_ao_sc = (gastos_do_mes_mais_recente / gastos_do_mes_mais_recente.loc['42 Santa Catarina'])
ax = gastos_recente_em_funcao_ao_sc.sort_values(ascending=False).plot(kind='bar', grid=True, figsize=(10, 6))
ax.set_title("Gastos dos estados referente a internações no SUS de Agosto de 2020 em função aos gastos de Santa Catarina")
plt.ylim(0, 9)
plt.show()

# %% [markdown]
# Descrição gráfico
#
# - Título: Gastos dos estados referente a internações no SUS de Agosto de 2020 em função aos gastos de Santa Catarina
# -Base de dados utilizada: Variável gastos_recente_em_funcao_ao_df
# - Tipo de gráfico: Barra
# - Eixo X: Estados
# - Eixo Y: Valores em função do Distrito Federal
# - O que está sendo mostrado: Neste gráfico é mostrado a proporção de diferença entre os gastos dos Estados em função de Santa Catarina. São Paulo possuí 7 vezes o valor de gastos de Santa Catarina

# %% [markdown]
# ## Desafio: gasto por população de dois esados (escolha dois estados)

# %% [markdown]
# https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o

# %%
dict_estado_populacao = {'35 São Paulo':	46289333,	
'31 Minas Gerais':	21331292,
'33 Rio de Janeiro':	17366189,
'29 Bahia':	14930634,
'41 Paraná':	11516840,
'43 Rio Grande do Sul':	11422973,
'26 Pernambuco':	9616621,
'23 Ceará':	9187103,
'15 Pará':	8690745,
'42 Santa Catarina':	7279638,
'52 Goiás':	7142070,
'21 Maranhão':	7127460,
'13 Amazonas':	4228381,
'32 Espírito Santo':	4064052,
'25 Paraíba':	4039277,
'24 Rio Grande do Norte':	3534165,
'51 Mato Grosso':	3526220,
'27 Alagoas':	3351543,
'22 Piauí':	3281480,
'53 Distrito Federal':	3055149,
'50 Mato Grosso do Sul':	2809394,
'28 Sergipe':	2318822,
'11 Rondônia':	1796460,
'17 Tocantins':	1590248,
'12 Acre':	894470,
'16 Amapá':	861773,
'14 Roraima':	631181}

# %%
gasto_por_hab_por_estado = [[usaveis["Total"].loc[estado] / dict_estado_populacao[estado], dict_estado_populacao[estado]] for estado in dict_estado_populacao.keys()]
df_gasto_por_hab = pd.DataFrame(data=gasto_por_hab_por_estado, index=dict_estado_populacao.keys(), columns=['Gasto por habitante', 'Num de Habitantes'])
df_gasto_por_hab.sort_values(by='Num de Habitantes', ascending=False)['Gasto por habitante'].plot(kind='bar', grid=True, figsize=(10, 6))
plt.title("Gastos por habitantes dos estados referente a internações no SUS de 2008 a 2020 ordenado por população")
plt.show()

# %% [markdown]
# Descrição gráfico
#
# * Título: Gastos por habitantes dos estados referente a internações no SUS de 2008 a 2020 ordenado por população
# *Base de dados utilizada: Variável df_gasto_por_hab
# *Tipo de gráfico: Barra
# *Eixo X: Estados
# *Eixo Y: Gasto por habitante
# *O que está sendo mostrado: Neste gráfico é mostrado o gasto por habitante referente a cada Estado no período entre 2008 e 2020.

# %%
def custo_hab(populacao_A, estado_A, populacao_B, estado_B): # Função para fazer cálculo por habitante comparando entre dois estados.
  gasto_A = usaveis["Total"].loc[estado_A] / populacao_A
  gasto_B = usaveis["Total"].loc[estado_B] / populacao_B
  df_gasto_por_hab = pd.DataFrame(data=[gasto_A, gasto_B], index=[estado_A, estado_B], columns=['Gasto por habitante'])
  df_gasto_por_hab.plot(kind='bar', grid=True, figsize=(10,6))

# %%
custo_hab(46289333, '35 São Paulo', 631181, '14 Roraima')

# %% [markdown]
# Descrição gráfico
#
# * Título: Sem título
# *Base de dados utilizada: Variável df_gasto_por_hab
# *Tipo de gráfico: Barra
# *Eixo X: Estados
# *Eixo Y: Gasto por habitante
# *O que está sendo mostrado: Neste gráfico é mostrado um comparativo direto entre os Estados de São Paulo e Roraima. Em São Paulo podemos observar os gastos em torno de 800 reais e em Roraima em torno de 500 reais.

# %% [markdown]
# ## Desafio: explore e levante hipóteses e perguntas

# %% [markdown]
# ## Super Desafio: Escolha outro valor fora do Valor Aprovado no TABNET e explore
